# %% [markdown]
# This ipynb is to test my adjustments to how MAML works in my metaSB3 architecture

# %%
#!pip install -e "stable-baselines3-master\stable-baselines3-master"

# %% [markdown]
# ## Performing (non-robust) meta learning with the Khazad-Dum enviornment

# %%
#Perform imports
import random

import numpy as np
import torch
from torch import optim
from tqdm import tqdm

import gymnasium as gym


from stable_baselines3 import A2C,PPO

from stable_baselines3.common.logger import configure


import matplotlib.pyplot as plt


device = 'cpu'# 'cuda' #  #doing cpu as A2C with MlpPolicy (rather than CNNpolicy) in stablebaseline is faster on CPU, and the meta gradinet beign faster on GPU (even if it is) is not *that* much faster - it is about two(ish) times slower overall based on one run each with two meta iterations, so better on cpu in this case
torch.set_default_device(device)
# Out:
# C:\Users\fabia\Documents\GitHub\MetaStableBaselines3\proj_code\stable-baselines3-master\stable-baselines3-master\stable_baselines3\common\on_policy_algorithm.py:562: SyntaxWarning: invalid escape sequence '\e'
#   For {policy}, find risk bound \epsilon and performance guarantee \tilde{J} s.t. {policy} is certifiably robust with {confidence_level}.

# %%
model_save_path = "saved_models\\16May25_newMAMLtest1_PPO" #simulatenously testing my new maml syntax out and doing PPO (if somethings up, then try A2C with my new maml syntax to see if its my PPO that is wrong or the MAML syntax (too?))

# %%
import os
os.mkdir(model_save_path)

# %%
##Set up for meta learning

#Hyperparameters
adapt_lr =  7e-4
meta_lr = 0.0005 
meta_iterations = 100#500#1250
adapt_timesteps = 32*4 #for this enviornment, each episode is exactly 32 timesteps, so multiple of 32 means full number of eps experienced for each task
eval_timesteps = 100
tasks_per_loop = 40#60
adapt_visualisations = 15
M=1

vis_timesteps = meta_iterations//adapt_visualisations #denominator is number of visualisations we want
if vis_timesteps == 0:
    vis_timesteps = 1 

#Make meta-environment
import fabian.envs.khazad_dum_gymn 
env = gym.make("KhazadDum-v1") # can access wrapped env with "env.unwrapped" (e.g. to reset task)
env.unwrapped.exp_bonus = 1; env.unwrapped.bridge_bonus_factor = 2 #this should incentivise getting to the target asap, and incentivise going onto the bridge

#Make meta-policy and meta-optimiser
meta_agent = PPO("MlpPolicy", env, verbose=0, learning_rate=adapt_lr, device=device,
                 meta_learning=True, M=M, adapt_timesteps=adapt_timesteps, eval_timesteps=eval_timesteps) #we train the meta_agent to do well at adapting to new envs (i.e. meta learning) in our env distribution
meta_opt = optim.Adam(meta_agent.policy.parameters(), lr=meta_lr)

#Logging variables
meta_losses = []
meta_rets = []
best_meta_ret = None
best_meta_ret_it = -1
# Out:
# c:\Users\fabia\anaconda3\envs\projdist\Lib\site-packages\gymnasium\envs\registration.py:487: UserWarning: WARN: The environment creator metadata doesn't include `render_modes`, contains: ['render.modes']
#   logger.warn(

# %%
#Quick sidebar looking into how PPO works
from stable_baselines3 import PPO
PPO_agent = PPO("MlpPolicy", env, verbose=0, learning_rate=adapt_lr, device=device,meta_learning=True, M=M, adapt_timesteps=adapt_timesteps, eval_timesteps=eval_timesteps)
PPO_agent.learn(total_timesteps = 32*8)
#yeah, PPO has a feature that it does several optimisation passes over each bit of data:
#https://deepwiki.com/DLR-RM/stable-baselines3/3.1-on-policy-algorithms

# %%
print(env)
# Out:
# <OrderEnforcing<PassiveEnvChecker<KhazadDum<KhazadDum-v1>>>>

# %%
print(meta_agent._wrap_env(env))
# Out:
# <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x0000029476047610>

# %%
#Outer meta-learning loop
for meta_it in tqdm(range(meta_iterations)):
    meta_loss = 0
    meta_ret = 0
    #Have agent adapt to tasks one by one
    for t in (range(tasks_per_loop)):
        task_loss, task_return, _ = meta_agent.meta_adapt() #adapt to a randomly selected task {M} times
        meta_loss+=task_loss; meta_ret +=task_return

    #Perform gradient update on meta learning parameters
    meta_loss/=tasks_per_loop #normalise, so that learning rate need not depend on tasks/loop
    meta_ret/=tasks_per_loop
    
    meta_opt.zero_grad()
    meta_loss.backward()
    meta_opt.step()

    #Track meta_training curve
    meta_losses.append(meta_loss.detach().item())
    meta_rets.append(meta_ret.item())


    if meta_it % vis_timesteps == 0:
        #Output training info to console
        print(f"Meta loop {meta_it+1}/{meta_iterations} complete, validation loss: {meta_loss.detach().item()}, validation return: {meta_ret}")

        #Qualitative plot of adapted policy
        fig, ax = plt.subplots()
        ax = env.unwrapped.show_state(ax)    
        fig.show()

#TODO: note that the way I am doing MAML relies very much on the get_loss_rets function being right, as that loss is what I then adjust to optimise the model. It is also what is reported as the validation loss - if that is no good, then the model won't train right
#The fact that the validation loss is getting nicely lower but the return is not improving may be a bad sign, but we will have to see!

#Does doing awawy with the clipping cause me to lose something important, perhaps because the loss function may actually be super silly without clipping and so i screw it up? that doesnt really make sense as i am just using the normal loss function for evaluating
# a bunch of rollouts, it seems like the right function to use and then i am optimising the parameters of the policy?
# ^ the thing is, I dont necessarily just want the loss to be 'the thing i want' (i.e. a good final return) if that means we dont incentivise other things we know we need to get the thing I want (e.g. good value estimation)

#TODO: check that meta_agent.policy.parameters() are indeed the parameters i wanna be optimising in PPO, surely they are? If not maybe that is a function i should make in OPA class that is implemented by subclasses that just returns all the aprameters to be meta optimised?
# also maybe check online (even llms?) what may be going on and how to do meta learning with a PPO agent
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]C:\Users\fabia\AppData\Local\Temp\ipykernel_17868\2584235029.py:30: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
#   1%|          | 1/100 [05:46<9:32:25, 346.92s/it]
# Meta loop 1/100 complete, validation loss: 0.060829490423202515, validation return: -0.18715718388557434
#   7%|▋         | 7/100 [37:32<8:24:32, 325.51s/it]
# Meta loop 7/100 complete, validation loss: 0.05676375702023506, validation return: -0.2940530776977539
#  13%|█▎        | 13/100 [3:22:55<29:12:42, 1208.76s/it]
# Meta loop 13/100 complete, validation loss: 0.052793871611356735, validation return: -0.40057212114334106
#  19%|█▉        | 19/100 [4:01:35<10:44:27, 477.37s/it]
# Meta loop 19/100 complete, validation loss: 0.05027296394109726, validation return: -0.5121361017227173
#  25%|██▌       | 25/100 [4:37:39<8:08:36, 390.88s/it]
# Meta loop 25/100 complete, validation loss: 0.047812554985284805, validation return: -0.6299276947975159
#  31%|███       | 31/100 [5:12:07<6:36:25, 344.71s/it]
# Meta loop 31/100 complete, validation loss: 0.04609805718064308, validation return: -0.7592949271202087
#  37%|███▋      | 37/100 [5:46:19<6:16:35, 358.66s/it]
# Meta loop 37/100 complete, validation loss: 0.04439648613333702, validation return: -0.9091207385063171
#  43%|████▎     | 43/100 [7:03:23<7:10:21, 453.01s/it]
# Meta loop 43/100 complete, validation loss: 0.04349647834897041, validation return: -1.0728795528411865
#  49%|████▉     | 49/100 [7:33:09<4:29:16, 316.79s/it]
# Meta loop 49/100 complete, validation loss: 0.03973633795976639, validation return: -1.2529869079589844
#  55%|█████▌    | 55/100 [8:02:50<3:45:01, 300.04s/it]
# Meta loop 55/100 complete, validation loss: 0.034951355308294296, validation return: -1.4569122791290283
#  61%|██████    | 61/100 [8:32:41<3:15:27, 300.71s/it]
# Meta loop 61/100 complete, validation loss: 0.026010802015662193, validation return: -1.6665760278701782
#  67%|██████▋   | 67/100 [9:03:34<2:48:14, 305.88s/it]
# Meta loop 67/100 complete, validation loss: 0.012879805639386177, validation return: -1.8959770202636719
#  73%|███████▎  | 73/100 [9:34:19<2:18:40, 308.15s/it]
# Meta loop 73/100 complete, validation loss: 0.004648537375032902, validation return: -2.114736318588257
#  79%|███████▉  | 79/100 [10:04:47<1:46:57, 305.58s/it]
# Meta loop 79/100 complete, validation loss: -0.004506479017436504, validation return: -2.332613945007324
#  85%|████████▌ | 85/100 [10:35:24<1:16:23, 305.59s/it]
# Meta loop 85/100 complete, validation loss: -0.00830772239714861, validation return: -2.533799648284912
#  91%|█████████ | 91/100 [11:06:41<46:38, 310.90s/it]
# Meta loop 91/100 complete, validation loss: -0.007970942184329033, validation return: -2.7152814865112305
#  97%|█████████▋| 97/100 [11:37:10<15:15, 305.14s/it]
# Meta loop 97/100 complete, validation loss: -0.007584375329315662, validation return: -2.8752846717834473
# 100%|██████████| 100/100 [11:52:36<00:00, 427.57s/it]

# %%
#Outer meta-learning loop
for meta_it in tqdm(range(40)):
    meta_loss = 0
    meta_ret = 0
    #Have agent adapt to tasks one by one
    for t in (range(tasks_per_loop)):
        task_loss, task_return, _ = meta_agent.meta_adapt() #adapt to a randomly selected task {M} times
        meta_loss+=task_loss; meta_ret +=task_return

    #Perform gradient update on meta learning parameters
    meta_loss/=tasks_per_loop #normalise, so that learning rate need not depend on tasks/loop
    meta_ret/=tasks_per_loop
    
    meta_opt.zero_grad()
    meta_loss.backward()
    meta_opt.step()

    #Track meta_training curve
    meta_losses.append(meta_loss.detach().item())
    meta_rets.append(meta_ret.item())


    if meta_it % vis_timesteps == 0:
        #Output training info to console
        print(f"Meta loop {meta_it+1}/{meta_iterations} complete, validation loss: {meta_loss.detach().item()}, validation return: {meta_ret}")

        #Qualitative plot of adapted policy
        fig, ax = plt.subplots()

        ax = env.unwrapped.show_state(ax)    
        fig.show()
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]C:\Users\fabia\AppData\Local\Temp\ipykernel_17868\2543746930.py:30: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
#   2%|▎         | 1/40 [05:04<3:17:38, 304.06s/it]
# Meta loop 1/100 complete, validation loss: 0.008372903801500797, validation return: -2.9675493240356445
#  18%|█▊        | 7/40 [35:25<2:47:59, 305.44s/it]
# Meta loop 7/100 complete, validation loss: 0.018198948353528976, validation return: -3.0735650062561035
#  32%|███▎      | 13/40 [1:06:16<2:17:25, 305.39s/it]
# Meta loop 13/100 complete, validation loss: 0.00689075980335474, validation return: -3.130547523498535
#  48%|████▊     | 19/40 [1:36:43<1:46:49, 305.22s/it]
# Meta loop 19/100 complete, validation loss: -0.015304217115044594, validation return: -3.144385576248169
#  62%|██████▎   | 25/40 [2:07:00<1:15:45, 303.01s/it]
# Meta loop 25/100 complete, validation loss: -0.03467207029461861, validation return: -3.119234323501587
#  78%|███████▊  | 31/40 [2:37:17<45:13, 301.52s/it]
# Meta loop 31/100 complete, validation loss: -0.048373207449913025, validation return: -3.0643458366394043
#  92%|█████████▎| 37/40 [3:08:09<15:21, 307.20s/it]
# Meta loop 37/100 complete, validation loss: -0.07866813987493515, validation return: -2.9721200466156006
# 100%|██████████| 40/40 [3:23:23<00:00, 305.09s/it]

# %%
##Plot meta learning curves
xs = range(len(meta_losses))

plt.plot(xs, meta_losses)
plt.xlabel('Meta learning steps')
plt.ylabel('Validation loss')
plt.title('Meta learning curve - loss')
plt.show()

plt.plot(xs, meta_rets)
plt.xlabel('Meta learning steps')
plt.ylabel('Validation return')
plt.title('Meta learning curve - return')
plt.show()

# %% [markdown]
# ^ interstingly, it does look like this follows the pattern of as we decrease loss, retrun gets worse theb maybe it starts getting better again? This may mean my implementation is all good - meaning both my PPO implementation and MAML implementation are good yay. Hopefully. this actually looks like a nicer meta trainign curve than we have seenn for A2C, which may be promising!

# %%
torch.save(meta_agent.policy.state_dict(), f"{model_save_path}/final")

# %%
meta_iterations = 21

#Outer meta-learning loop
for meta_it in tqdm(range(meta_iterations)):
    meta_loss = 0
    meta_ret = 0
    #Have agent adapt to tasks one by one
    for t in (range(tasks_per_loop)):
        task_loss, task_return, _ = meta_agent.meta_adapt() #adapt to a randomly selected task {M} times
        meta_loss+=task_loss; meta_ret +=task_return

    #Perform gradient update on meta learning parameters
    meta_loss/=tasks_per_loop #normalise, so that learning rate need not depend on tasks/loop
    meta_ret/=tasks_per_loop
    
    meta_opt.zero_grad()
    meta_loss.backward()
    meta_opt.step()

    #Track meta_training curve
    meta_losses.append(meta_loss.detach().item())
    meta_rets.append(meta_ret.item())


    if meta_it % vis_timesteps == 0:
        #Output training info to console
        print(f"Meta loop {meta_it+1}/{meta_iterations} complete, validation loss: {meta_loss.detach().item()}, validation return: {meta_ret}")

        #Qualitative plot of adapted policy
        fig, ax = plt.subplots()
        ax = env.unwrapped.show_state(ax)    
        fig.show()
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]C:\Users\fabia\AppData\Local\Temp\ipykernel_17868\3387452001.py:32: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
#   5%|▍         | 1/21 [05:28<1:49:31, 328.59s/it]
# Meta loop 1/21 complete, validation loss: -0.10230131447315216, validation return: -2.9181840419769287
#  33%|███▎      | 7/21 [42:03<1:24:30, 362.17s/it]
# Meta loop 7/21 complete, validation loss: -0.09049124270677567, validation return: -2.8663268089294434
#  62%|██████▏   | 13/21 [1:12:47<41:51, 313.97s/it]
# Meta loop 13/21 complete, validation loss: 0.02637956477701664, validation return: -2.9181764125823975
#  90%|█████████ | 19/21 [1:46:03<10:55, 327.95s/it]
# Meta loop 19/21 complete, validation loss: 0.06438171118497849, validation return: -2.9808602333068848
# 100%|██████████| 21/21 [1:56:20<00:00, 332.39s/it]

# %%
##Plot meta learning curves
xs = range(21)

plt.plot(xs, meta_losses[-21:])
plt.xlabel('Meta learning steps')
plt.ylabel('Validation loss')
plt.title('Meta learning curve - loss')
plt.show()

plt.plot(xs, meta_rets[-21:])
plt.xlabel('Meta learning steps')
plt.ylabel('Validation return')
plt.title('Meta learning curve - return')
plt.show()

# %%
##Plot meta learning curves
xs = range(len(meta_losses))

plt.plot(xs, meta_losses)
plt.xlabel('Meta learning steps')
plt.ylabel('Validation loss')
plt.title('Meta learning curve - loss')
plt.show()

plt.plot(xs, meta_rets)
plt.xlabel('Meta learning steps')
plt.ylabel('Validation return')
plt.title('Meta learning curve - return')
plt.show()

# %% [markdown]
# ^ ahh well it looks like that did not really last, and that the return is creeping down again but then a final flick up. Very wierd as that is basically the same pattern but repeated again, especially when we view it zoomed in (the two plots above). I dont think there is anything too eep with that observation, though, especially as the first training was two seperate bits anyway and that was all cotninuous. I will train for even longer, i suppose, and see if the return heads up again...? Looking at the paths generated, it does seem to just essentially be exploring right now, which may explain the loss behaviour- changing stuff results in sorta chaotic results where moving in the direction of steepest descent with the loss function changes something small that may improve stuff or may not, because at this point in our search we have learnt to go around but have not yet learnt how to reach the endpoint (and then ofc we need tpo learn to take the shortest route to get to the true optimum which presumably will send the loss way up again and the return way down?)
#
# So i think the KD problem is just a weird environment to learn, and we should continue training!

# %%
torch.save(meta_agent.policy.state_dict(), f"{model_save_path}/final2")

# %%
meta_iterations = 43

#Outer meta-learning loop
for meta_it in tqdm(range(meta_iterations)):
    meta_loss = 0
    meta_ret = 0
    #Have agent adapt to tasks one by one
    for t in (range(tasks_per_loop)):
        task_loss, task_return, _ = meta_agent.meta_adapt() #adapt to a randomly selected task {M} times
        meta_loss+=task_loss; meta_ret +=task_return

    #Perform gradient update on meta learning parameters
    meta_loss/=tasks_per_loop #normalise, so that learning rate need not depend on tasks/loop
    meta_ret/=tasks_per_loop
    
    meta_opt.zero_grad()
    meta_loss.backward()
    meta_opt.step()

    #Track meta_training curve
    meta_losses.append(meta_loss.detach().item())
    meta_rets.append(meta_ret.item())


    if meta_it % vis_timesteps == 0:
        #Output training info to console
        print(f"Meta loop {meta_it+1}/{meta_iterations} complete, validation loss: {meta_loss.detach().item()}, validation return: {meta_ret}")

        #Qualitative plot of adapted policy
        fig, ax = plt.subplots()
        ax = env.unwrapped.show_state(ax)    
        fig.show()
# Out:
#   0%|          | 0/43 [00:00<?, ?it/s]C:\Users\fabia\AppData\Local\Temp\ipykernel_17868\1418902018.py:32: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
#   2%|▏         | 1/43 [05:15<3:40:52, 315.54s/it]
# Meta loop 1/43 complete, validation loss: 0.030534589663147926, validation return: -2.972123622894287
#  16%|█▋        | 7/43 [37:08<3:08:01, 313.38s/it]
# Meta loop 7/43 complete, validation loss: -0.04439759626984596, validation return: -2.847238063812256
#  30%|███       | 13/43 [1:08:17<2:36:11, 312.37s/it]
# Meta loop 13/43 complete, validation loss: -0.031048525124788284, validation return: -2.5758399963378906
#  44%|████▍     | 19/43 [1:40:36<2:07:58, 319.94s/it]
# Meta loop 19/43 complete, validation loss: -0.003044828772544861, validation return: -2.155938148498535
#  58%|█████▊    | 25/43 [2:11:49<1:34:09, 313.87s/it]
# Meta loop 25/43 complete, validation loss: 0.020132986828684807, validation return: -1.608971357345581
#  72%|███████▏  | 31/43 [2:42:44<1:01:58, 309.92s/it]
# Meta loop 31/43 complete, validation loss: 0.03739989921450615, validation return: -1.0856331586837769
#  86%|████████▌ | 37/43 [3:20:50<37:28, 374.76s/it]
# Meta loop 37/43 complete, validation loss: 0.03632412105798721, validation return: -0.625393271446228
# 100%|██████████| 43/43 [3:52:25<00:00, 324.31s/it]
# Meta loop 43/43 complete, validation loss: 0.017705798149108887, validation return: -0.24170620739459991

# %%
##Plot meta learning curves
xs = range(len(meta_losses))

plt.plot(xs, meta_losses)
plt.xlabel('Meta learning steps')
plt.ylabel('Validation loss')
plt.title('Meta learning curve - loss')
plt.show()

plt.plot(xs, meta_rets)
plt.xlabel('Meta learning steps')
plt.ylabel('Validation return')
plt.title('Meta learning curve - return')
plt.show()

# %% [markdown]
# eyyyy nice! still needs to learn the quicker way to get there though, which is over the bridge! i think the incentive should be there for it to go over the bridge (the same setup did give A2C the incentive) so hopefully with some more training it will learn to do that! probably in the meantime though it will have a big decrease in performance tho? There is also a chance it will get stuck in this local optimum but hopefully not - A2C diodnt!

# %% [markdown]
# looking at my a2c training for non robust, it seems to have learnt to go down the bridge pretty quickly, much quicker than this trainign did - I wonder if it ended up taking the robust method and got caught in the dip> maybe? if after these extra iterations it still isnt particularly good i should consier setting up maybe 3 paralell ppo trainings on the server (non robust) to see if it does sometimes get the bridge and sometimes not maybe its smth about the loss landscape?

# %%
torch.save(meta_agent.policy.state_dict(), f"{model_save_path}/final3")

# %%
meta_iterations = 2

#Outer meta-learning loop
for meta_it in tqdm(range(meta_iterations)):
    meta_loss = 0
    meta_ret = 0
    #Have agent adapt to tasks one by one
    for t in (range(tasks_per_loop)):
        task_loss, task_return, _ = meta_agent.meta_adapt() #adapt to a randomly selected task {M} times
        meta_loss+=task_loss; meta_ret +=task_return

    #Perform gradient update on meta learning parameters
    meta_loss/=tasks_per_loop #normalise, so that learning rate need not depend on tasks/loop
    meta_ret/=tasks_per_loop
    
    meta_opt.zero_grad()
    meta_loss.backward()
    meta_opt.step()

    #Track meta_training curve
    meta_losses.append(meta_loss.detach().item())
    meta_rets.append(meta_ret.item())


    if meta_it % vis_timesteps == 0:
        #Output training info to console
        print(f"Meta loop {meta_it+1}/{meta_iterations} complete, validation loss: {meta_loss.detach().item()}, validation return: {meta_ret}")

        #Qualitative plot of adapted policy
        fig, ax = plt.subplots()
        ax = env.unwrapped.show_state(ax)    
        fig.show()
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]C:\Users\fabia\AppData\Local\Temp\ipykernel_17868\3128358419.py:32: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
#  50%|█████     | 1/2 [05:09<05:09, 309.41s/it]
# Meta loop 1/2 complete, validation loss: 0.015019712969660759, validation return: -0.21523642539978027
# 100%|██████████| 2/2 [10:17<00:00, 308.81s/it]

# %%
##Plot meta learning curves
xs = range(len(meta_losses))

plt.plot(xs, meta_losses)
plt.xlabel('Meta learning steps')
plt.ylabel('Validation loss')
plt.title('Meta learning curve - loss')
plt.show()

plt.plot(xs, meta_rets)
plt.xlabel('Meta learning steps')
plt.ylabel('Validation return')
plt.title('Meta learning curve - return')
plt.show()

# %%
torch.save(meta_agent.policy.state_dict(), f"{model_save_path}/final4")

# %%
meta_iterations = 2

#Outer meta-learning loop
for meta_it in tqdm(range(meta_iterations)):
    meta_loss = 0
    meta_ret = 0
    #Have agent adapt to tasks one by one
    for t in (range(tasks_per_loop)):
        task_loss, task_return, _ = meta_agent.meta_adapt() #adapt to a randomly selected task {M} times
        meta_loss+=task_loss; meta_ret +=task_return

    #Perform gradient update on meta learning parameters
    meta_loss/=tasks_per_loop #normalise, so that learning rate need not depend on tasks/loop
    meta_ret/=tasks_per_loop
    
    meta_opt.zero_grad()
    meta_loss.backward()
    meta_opt.step()

    #Track meta_training curve
    meta_losses.append(meta_loss.detach().item())
    meta_rets.append(meta_ret.item())


    if meta_it % vis_timesteps == 0:
        #Output training info to console
        print(f"Meta loop {meta_it+1}/{meta_iterations} complete, validation loss: {meta_loss.detach().item()}, validation return: {meta_ret}")

        #Qualitative plot of adapted policy
        fig, ax = plt.subplots()
        ax = env.unwrapped.show_state(ax)    
        fig.show()
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]C:\Users\fabia\AppData\Local\Temp\ipykernel_17868\3128358419.py:32: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
#  50%|█████     | 1/2 [05:03<05:03, 303.57s/it]
# Meta loop 1/2 complete, validation loss: -0.004325208719819784, validation return: -0.13351158797740936
# 100%|██████████| 2/2 [10:14<00:00, 307.27s/it]

# %%
meta_iterations = 100

#Outer meta-learning loop
for meta_it in tqdm(range(meta_iterations)):
    meta_loss = 0
    meta_ret = 0
    #Have agent adapt to tasks one by one
    for t in (range(tasks_per_loop)):
        task_loss, task_return, _ = meta_agent.meta_adapt() #adapt to a randomly selected task {M} times
        meta_loss+=task_loss; meta_ret +=task_return

    #Perform gradient update on meta learning parameters
    meta_loss/=tasks_per_loop #normalise, so that learning rate need not depend on tasks/loop
    meta_ret/=tasks_per_loop
    
    meta_opt.zero_grad()
    meta_loss.backward()
    meta_opt.step()

    #Track meta_training curve
    meta_losses.append(meta_loss.detach().item())
    meta_rets.append(meta_ret.item())


    if meta_it % vis_timesteps == 0:
        #Output training info to console
        print(f"Meta loop {meta_it+1}/{meta_iterations} complete, validation loss: {meta_loss.detach().item()}, validation return: {meta_ret}")

        #Qualitative plot of adapted policy
        fig, ax = plt.subplots()
        ax = env.unwrapped.show_state(ax)    
        fig.show()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]C:\Users\fabia\AppData\Local\Temp\ipykernel_17868\4105394508.py:32: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
#   1%|          | 1/100 [07:24<12:14:09, 444.94s/it]
# Meta loop 1/100 complete, validation loss: -0.016382461413741112, validation return: -0.020777469500899315
#   7%|▋         | 7/100 [53:40<11:36:29, 449.35s/it]
# Meta loop 7/100 complete, validation loss: -0.058492474257946014, validation return: 0.1597858965396881
#  13%|█▎        | 13/100 [1:33:53<9:37:38, 398.37s/it]
# Meta loop 13/100 complete, validation loss: -0.09225073456764221, validation return: 0.31285399198532104
#  19%|█▉        | 19/100 [6:26:48<43:47:46, 1946.50s/it]
# Meta loop 19/100 complete, validation loss: -0.10862956196069717, validation return: 0.36992672085762024
#  25%|██▌       | 25/100 [6:59:22<10:43:00, 514.40s/it]
# Meta loop 25/100 complete, validation loss: -0.09969265013933182, validation return: 0.3567327857017517
#  31%|███       | 31/100 [7:30:51<6:29:00, 338.26s/it]
# Meta loop 31/100 complete, validation loss: -0.0907880887389183, validation return: 0.28960588574409485
#  37%|███▋      | 37/100 [8:02:31<5:36:49, 320.78s/it]
# Meta loop 37/100 complete, validation loss: -0.08990275114774704, validation return: 0.19946816563606262
#  43%|████▎     | 43/100 [8:33:44<4:58:48, 314.53s/it]
# Meta loop 43/100 complete, validation loss: -0.10002805292606354, validation return: 0.1051909327507019
#  49%|████▉     | 49/100 [9:04:53<4:26:21, 313.36s/it]
# Meta loop 49/100 complete, validation loss: -0.10400658845901489, validation return: 0.015608886256814003
#  55%|█████▌    | 55/100 [9:36:45<4:00:10, 320.24s/it]
# Meta loop 55/100 complete, validation loss: -0.11130086332559586, validation return: -0.06356893479824066
#  61%|██████    | 61/100 [10:07:59<3:23:29, 313.06s/it]
# Meta loop 61/100 complete, validation loss: -0.10514333099126816, validation return: -0.12376091629266739
#  67%|██████▋   | 67/100 [10:39:11<2:51:08, 311.18s/it]
# Meta loop 67/100 complete, validation loss: -0.08635474741458893, validation return: -0.17679636180400848
#  73%|███████▎  | 73/100 [11:10:23<2:20:28, 312.18s/it]
# Meta loop 73/100 complete, validation loss: -0.038605548441410065, validation return: -0.20922449231147766
#  79%|███████▉  | 79/100 [11:42:03<1:51:03, 317.31s/it]
# Meta loop 79/100 complete, validation loss: -0.008362977765500546, validation return: -0.22009095549583435
#  85%|████████▌ | 85/100 [12:13:13<1:17:58, 311.90s/it]
# Meta loop 85/100 complete, validation loss: -3.274381015216932e-05, validation return: -0.21906009316444397
#  91%|█████████ | 91/100 [12:44:41<47:21, 315.74s/it]
# Meta loop 91/100 complete, validation loss: -0.02377184107899666, validation return: -0.20380370318889618
#  97%|█████████▋| 97/100 [13:16:00<15:31, 310.47s/it]
# Meta loop 97/100 complete, validation loss: -0.047488369047641754, validation return: -0.17151042819023132
# 100%|██████████| 100/100 [13:31:50<00:00, 487.10s/it]

# %%
##Plot meta learning curves
xs = range(len(meta_losses))

plt.plot(xs, meta_losses)
plt.xlabel('Meta learning steps')
plt.ylabel('Validation loss')
plt.title('Meta learning curve - loss')
plt.show()

plt.plot(xs, meta_rets)
plt.xlabel('Meta learning steps')
plt.ylabel('Validation return')
plt.title('Meta learning curve - return')
plt.show()

# %%
torch.save(meta_agent.policy.state_dict(), f"{model_save_path}/final5")

# %%
##Plot meta learning curves
xs = range(len(meta_losses))

plt.plot(xs, meta_losses)
plt.xlabel('Meta learning steps')
plt.ylabel('Validation loss')
plt.title('Meta learning curve - loss')
plt.show()

plt.plot(xs, meta_rets)
plt.xlabel('Meta learning steps')
plt.ylabel('Validation return')
plt.title('Meta learning curve - return')
plt.show()

# %%
#Load in enviornemnt that performed best against meta validation
#loaded_meta_agent.policy.load_state_dict(torch.load(f"{model_save_path}\\best_val_meta_ret", weights_only=True)) 
    #as can be seen in the learning curve above, the model with the best meta-return is very much not the one which actually performs the best (if we see it perform, we see it just geniunely does badly!)
    #TODO: what is going on with that?

#loaded_meta_agent.policy.load_state_dict(torch.load(f"{model_save_path}\\meta_it_{495}", weights_only=True)) 

meta_agent.policy.load_state_dict(torch.load(f"{model_save_path}\\final5", weights_only=True)) 


    #can also load in intermediate saved envs from training
# Out:
# <All keys matched successfully>

# %%
#Seeing it manage in a range of environments - this one is taken from loading the best model from a 400 meta-step training, which clearly isnt quite all that 
dim = 3
fig, axs = plt.subplots(dim, dim, figsize=(10, 8))

for t in tqdm(range(dim*dim)):
    #Perform few shot adaption to environment
    env.unwrapped.reset_task() #randomly selects task from environment to reset it to
    meta_agent.learn(total_timesteps=adapt_timesteps) #adapt the meta agent to this task

    #Test against a new trajectory from that state (else we are showing something it trained to and before the final training step)
    meta_agent.evaluate_policy(total_timesteps=32)

    #TODO: IMPROTANT TO NOTE - for fair evaluation of a MAML-meta-policy, as this is all about few-shot learning, we need to evaluate its performance to a task after having had a chance to adapt to that task

    #Plot this run
    x = t//dim
    y = t%dim
    axs[x,y] = env.unwrapped.show_state(axs[x,y])    
    axs[x,y].set_axis_off()
    
plt.tight_layout()

fig.show()


#TODO: i should do this again with a non meta-trained model that just learns for a single task and see how it does worse qualitatively
# Out:
# 100%|██████████| 9/9 [01:05<00:00,  7.25s/it]
# C:\Users\fabia\AppData\Local\Temp\ipykernel_17868\3705443118.py:23: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
